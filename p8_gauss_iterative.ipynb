# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Ejercicio 1

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[2,1],[3,2]]
b = [5,8]

x, traj = gauss_seidel(A,b,[0,0],tol=1e-5, max_iter=5)
# Out:
# [02-12 16:09:38][INFO][Lasca] 2026-02-12 16:09:38.817912
# [02-12 16:09:39][INFO][Lasca] 2026-02-12 16:09:39.034738
# [02-12 16:09:39][INFO][Lasca] 2026-02-12 16:09:39.038537
# [02-12 16:09:39][INFO][Lasca] i= 0 x: [[0. 0.]]
# [02-12 16:09:39][INFO][Lasca] i= 1 x: [[2.5  0.25]]
# [02-12 16:09:39][INFO][Lasca] i= 2 x: [[2.375  0.4375]]
# [02-12 16:09:39][INFO][Lasca] i= 3 x: [[2.28125  0.578125]]
# [02-12 16:09:39][INFO][Lasca] i= 4 x: [[2.2109375  0.68359375]]
# [02-12 16:09:39][INFO][Lasca] i= 5 x: [[2.15820312 0.76269531]]
# [02-12 16:09:39][INFO][Lasca] i= 0 x: [[0. 0.]]
# [02-12 16:09:39][INFO][Lasca] i= 1 x: [[2.5  0.25]]
# [02-12 16:09:39][INFO][Lasca] i= 2 x: [[2.375  0.4375]]
# [02-12 16:09:39][INFO][Lasca] i= 3 x: [[2.28125  0.578125]]
# [02-12 16:09:39][INFO][Lasca] i= 4 x: [[2.2109375  0.68359375]]
# [02-12 16:09:39][INFO][Lasca] i= 5 x: [[2.15820312 0.76269531]]

# %%
import numpy as np

traj = np.array(traj)
x_values = traj[:,0]
y_values = traj[:,1]

print(x_values)
print(y_values)
# Out:
# [[2.5       ]
#  [2.5       ]
#  [2.375     ]
#  [2.375     ]
#  [2.28125   ]
#  [2.28125   ]
#  [2.2109375 ]
#  [2.2109375 ]
#  [2.15820312]
#  [2.15820312]]
# [[0.        ]
#  [0.25      ]
#  [0.        ]
#  [0.4375    ]
#  [0.        ]
#  [0.578125  ]
#  [0.        ]
#  [0.68359375]
#  [0.        ]
#  [0.76269531]]

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values 
y_values 

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ejercicio 2

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A2 = [[1,1],[-2,1]]
b2 = [6,0]

y, traj2 = gauss_jacobi(A2,b2,[0,0],tol=1e-5, max_iter=5)


print("Trajectoria",traj2)
# Out:
# [02-12 16:15:09][INFO][Lasca] i= 0 x: [[0. 0.]]
# [02-12 16:15:09][INFO][Lasca] i= 5 x: [[ 18. -12.]]
# Trajectoria [array([[6.],
#        [0.]]), array([[6.],
#        [0.]]), array([[6.],
#        [0.]]), array([[ 6.],
#        [12.]]), array([[-6.],
#        [ 0.]]), array([[-6.],
#        [12.]]), array([[-6.],
#        [ 0.]]), array([[ -6.],
#        [-12.]]), array([[18.],
#        [ 0.]]), array([[ 18.],
#        [-12.]])]

# %%
traj2 = np.array(traj2)
x_values2 = traj2[:,0]
y_values2 = traj2[:,1]

print(x_values2)
print(y_values2)
# Out:
# [[ 6.]
#  [ 6.]
#  [ 6.]
#  [ 6.]
#  [-6.]
#  [-6.]
#  [-6.]
#  [-6.]
#  [18.]
#  [18.]]
# [[  0.]
#  [  0.]
#  [  0.]
#  [ 12.]
#  [  0.]
#  [ 12.]
#  [  0.]
#  [-12.]
#  [  0.]
#  [-12.]]

# %% [markdown]
# # Código para dibujar

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values2
y_values2

import matplotlib.pyplot as plt

iterations = range(len(x_values2))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values2, y_values2, "o:", markersize=4)
plt.plot(x_values2[0], y_values2[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values2[-1], y_values2[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
