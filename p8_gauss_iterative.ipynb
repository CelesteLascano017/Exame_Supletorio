# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Ejercicio 1

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A = [[2,1],[3,2]]
b = [5,8]

x, traj = gauss_seidel(A,b,[0,1],tol=1e-7, max_iter=15)
# Out:
# [02-12 16:53:01][INFO][Lasca] i= 0 x: [[0. 1.]]
# [02-12 16:53:01][INFO][Lasca] i= 1 x: [[2. 1.]]

# %%
import matplotlib.pyplot as plt
x_values = [0, 2.5, 2.375, 2.28125,2.2109375,2.15820312,2.11865234, 2.08898926, 2.06674194, 2.05005646, 2.03754234,2.01187863, 2.00890897] 
y_values = [0, 0.25, 0.4375,0.578125,0.68359375, 0.76269531,0.82202148, 0.86651611, 0.89988708, 0.92491531, 0.94368649, 0.98218205, 0.98663654   ]

plt.plot(x, y, "o:", markersize=4)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria del método de Gauss-Seidel")
# Out:
# Text(0.5, 1.0, 'Trajectoria del método de Gauss-Seidel')

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values 
y_values 

import matplotlib.pyplot as plt

iterations = range(len(x_values))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values, y_values, "o:", markersize=4)
plt.plot(x_values[0], y_values[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values[-1], y_values[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)

  
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ejercicio 2

# %%
# %autoreload 2
from src import gauss_jacobi, gauss_seidel
A2 = [[1,1],[-2,1]]
b2 = [6,0]

y, traj2 = gauss_seidel(A2,b2,[2,4],tol=1e-5, max_iter=3)

print("Gauss-Seidel Solution:", y)
print("Trajectoria",traj2)
# Out:
# [02-12 16:54:28][INFO][Lasca] i= 0 x: [[2. 4.]]
# Gauss-Seidel Solution: [2.]
# Trajectoria [4.]

# %%
traj2 = np.array(traj2)
x_values2 = traj2[:,0]
y_values2 = traj2[:,1]

print(x_values2)
print(y_values2)
# Out:
# [[ 6.]
#  [ 6.]
#  [ 6.]
#  [ 6.]
#  [-6.]
#  [-6.]]
# [[ 0.]
#  [ 0.]
#  [ 0.]
#  [12.]
#  [ 0.]
#  [12.]]

# %% [markdown]
# # Código para dibujar

# %%
# Extraer valores de la trayectoria
# -- Datos de ejemplo --
x_values2
y_values2

import matplotlib.pyplot as plt

iterations = range(len(x_values2))

# Dibujar trajectoria en el espacio 2D
plt.plot(x_values2, y_values2, "o:", markersize=4)
plt.plot(x_values2[0], y_values2[0], "gd", markersize=8, label="$X_0$", alpha=0.8)
plt.plot(x_values2[-1], y_values2[-1], "ro", markersize=8, label="$X_{sol}$", alpha=0.8)
#Linea de convergencia
plt.plot([x_values2[0], x_values2[-1]], [y_values2[0], y_values2[-1]], "k--", alpha=0.5, label="Convergencia")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Trajectoria")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()


pendiente = (y_values2[-1] - y_values2[0]) / (x_values2[-1] - x_values2[0])
print("Pendiente de la linea de convergencia:", pendiente)
# Out:
# Pendiente de la linea de convergencia: [-1.]
